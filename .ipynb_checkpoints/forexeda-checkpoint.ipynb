# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as scs
import re
from datetime import datetime


# %matplotlib inline
plt.style.use('ggplot')
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
plt.rcParams["figure.figsize"] = (12,12)
pd.options.display.max_columns = None
# Out:
# <style>.container { width:100% !important; }</style>

# %%
ls
# Out:
# data/  forexeda.ipynb  getdata/  models/  README.md  resources/

# %%
df = pd.read_pickle('data/EUR_USD_M1')
df.set_index('time', inplace=True)
df.shape
# Out:
# (4644072, 6)

# %%
df.head()
# Out:
#                      volume   close    high     low    open  complete
# time
# 2005-01-02 18:29:00       1  1.3560  1.3560  1.3560  1.3560      True
# 2005-01-02 18:38:00       1  1.3560  1.3560  1.3560  1.3560      True
# 2005-01-02 18:51:00       1  1.3567  1.3567  1.3567  1.3567      True
# 2005-01-02 18:52:00       1  1.3565  1.3565  1.3565  1.3565      True
# 2005-01-02 18:55:00       1  1.3568  1.3568  1.3568  1.3568      True

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4644072 entries, 2005-01-02 18:29:00 to 2017-09-05 03:34:00
# Data columns (total 6 columns):
# volume      int64
# close       float64
# high        float64
# low         float64
# open        float64
# complete    bool
# dtypes: bool(1), float64(4), int64(1)
# memory usage: 217.0 MB

# %%
df = df.loc[datetime(2016, 12, 8):datetime(2016, 12, 10), :]
df.shape
# Out:
# (2658, 6)

# %%
df.head()
# Out:
#                      volume    close     high      low     open  complete
# time
# 2016-12-08 00:00:00      13  1.07593  1.07593  1.07577  1.07590      True
# 2016-12-08 00:01:00      10  1.07600  1.07610  1.07596  1.07596      True
# 2016-12-08 00:02:00       6  1.07610  1.07610  1.07598  1.07598      True
# 2016-12-08 00:03:00      16  1.07636  1.07641  1.07612  1.07612      True
# 2016-12-08 00:04:00       1  1.07634  1.07634  1.07634  1.07634      True

# %%
def plot_price(df, figtitle):
    fig, ax = plt.subplots()
    ax.plot(df['open'])
    ax.set_title(figtitle)

# %%
plot_price(df, 'EUR_USD_M1 2016-12-8 to 2016-12-10')

# %%
df['actual_up_down'] = np.sign(df['open']-df['open'].shift(1))

# %%
df['log_returns'] = np.log(df['open'] / df['open'].shift(1))
df['ari_returns'] = (df['open'] / df['open'].shift(1)) - 1

# %%
cols = []
for momentum in [15, 30, 60, 120]:
    col = 'position_{}'.format(momentum)
    df[col] = np.sign(df['log_returns'].rolling(momentum).mean()).shift(1) #the sign of the average returns of the last x candles
    cols.append(col)

# %%
df.head(20)
# Out:
#                      volume    close     high      low     open  complete  \
# time
# 2016-12-08 00:00:00      13  1.07593  1.07593  1.07577  1.07590      True
# 2016-12-08 00:01:00      10  1.07600  1.07610  1.07596  1.07596      True
# 2016-12-08 00:02:00       6  1.07610  1.07610  1.07598  1.07598      True
# 2016-12-08 00:03:00      16  1.07636  1.07641  1.07612  1.07612      True
# 2016-12-08 00:04:00       1  1.07634  1.07634  1.07634  1.07634      True
# 2016-12-08 00:05:00      24  1.07657  1.07670  1.07631  1.07631      True
# 2016-12-08 00:06:00       5  1.07653  1.07661  1.07653  1.07661      True
# 2016-12-08 00:09:00          NaN          NaN           NaN
# 2016-12-08 00:10:00          NaN          NaN           NaN
# 2016-12-08 00:11:00          NaN          NaN           NaN
# 2016-12-08 00:12:00          NaN          NaN           NaN
# 2016-12-08 00:13:00          NaN          NaN           NaN
# 2016-12-08 00:14:00          NaN          NaN           NaN
# 2016-12-08 00:17:00          NaN          NaN           NaN
# 2016-12-08 00:18:00          NaN          NaN           NaN
# 2016-12-08 00:19:00          NaN          NaN           NaN
# 2016-12-08 00:20:00          NaN          NaN           NaN
# 2016-12-08 00:21:00          NaN          NaN           NaN

# %%
strats = ['log_returns']
for col in cols:
    strat = 'strategy_{}'.format(col.split('_')[1])
    df[strat] = df[col] * df['log_returns'] #shift last sign one and multiply by return
    strats.append(strat)

# %%
fig, axes = plt.subplots()
cum_returns = df[strats].dropna().cumsum().apply(np.exp)-1 #you can add log returns and then transpose back with np.exp
cum_returns.plot(ax=axes)
plt.legend(loc='best')

# %% [markdown]
# # Data Preprocessing
#
# ## Expoenential Smoothing timeseries data?
# Exponential smoothing applies
# more weightage to the recent observation and exponentially decreasing weights to past observations.
# This smoothing removes random variation or noise from the historical data allowing the model to easily identify long term price trend in the stock price behavior. Technical indicators are then calculated from the exponentially smoothed time series data which are later organized into feature matrix.

# %% [markdown]
# # Target / Label
#
# target of i day is the np.sign((open i+d) - (open i))

# %%
df.head()
# Out:
#                      volume    close     high      low     open  complete  \
# time
# 2016-12-08 00:00:00      13  1.07593  1.07593  1.07577  1.07590      True
# 2016-12-08 00:01:00      10  1.07600  1.07610  1.07596  1.07596      True
# 2016-12-08 00:02:00       6  1.07610  1.07610  1.07598  1.07598      True
# 2016-12-08 00:03:00      16  1.07636  1.07641  1.07612  1.07612      True
# 2016-12-08 00:04:00       1  1.07634  1.07634  1.07634  1.07634      True
#
#                      actual_up_down  log_returns  ari_returns  position_15  \
# time
# 2016-12-08 00:00:00             NaN          NaN          NaN          NaN
# 2016-12-08 00:01:00             1.0     0.000056     0.000056          NaN
# 2016-12-08 00:02:00             1.0     0.000019     0.000019          NaN
# 2016-12-08 00:03:00             1.0     0.000130     0.000130          NaN
# 2016-12-08 00:04:00             1.0     0.000204     0.000204          NaN
#
#                      position_30  position_60  position_120  strategy_15  \
# time
# 2016-12-08 00:00:00          NaN          NaN           NaN          NaN
# 2016-12-08 00:01:00          NaN          NaN           NaN          NaN
# 2016-12-08 00:02:00          NaN          NaN           NaN          NaN
# 2016-12-08 00:03:00          NaN          NaN           NaN          NaN
# 2016-12-08 00:04:00          NaN          NaN           NaN          NaN
#
#                      strategy_30  strategy_60  strategy_120
# time
# 2016-12-08 00:00:00          NaN          NaN           NaN
# 2016-12-08 00:01:00          NaN          NaN           NaN
# 2016-12-08 00:02:00          NaN          NaN           NaN
# 2016-12-08 00:03:00          NaN          NaN           NaN
# 2016-12-08 00:04:00          NaN          NaN           NaN
